# %%
import pandas as pd

#read iris dataset into python

iris = pd.read_csv("Iris.csv")

# check the structure

print(iris.head())

print(iris.describe())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# ...

# %%
iris_by_species = iris.pivot_table(index='Species')
print(iris_by_species.head())
# Out:
#                     Id  PetalLengthCm  PetalWidthCm  SepalLengthCm  \
# Species
# Iris-setosa       25.5          1.464         0.244          5.006
# Iris-versicolor   75.5          4.260         1.326          5.936
# Iris-virginica   125.5          5.552         2.026          6.588
#
#                  SepalWidthCm
# Species
# Iris-setosa             3.418
# Iris-versicolor         2.770
# Iris-virginica          2.974

# %% [raw]
# iris_by_species = iris.groupby('Species')['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'].mean()
# print(iris_by_species)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
iris_by_species2 = iris.groupby('Species')['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'].mean()
print(iris_by_species2.head())
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa              5.006         3.418          1.464         0.244
# Iris-versicolor          5.936         2.770          4.260         1.326
# Iris-virginica           6.588         2.974          5.552         2.026

# %%
# %matplotlib inline
my_plot = iris_by_species2.plot(kind='bar')

# %%
# plotting sepal length vs sepal width to check for correlation
colors = ['red', 'blue','green']
iris.plot.scatter(x = "SepalWidthCm", y = "SepalLengthCm")

# %%
# plotting petal length vs petal width
iris.plot.scatter(x = "PetalWidthCm", y = "PetalLengthCm")

# %%
# plotting sepal length vs petal length
iris.plot.scatter(x = "SepalLengthCm", y = "PetalLengthCm", color = "green")

# %%
# plotting sepal width vs petal width
iris.plot.scatter(x = "SepalWidthCm", y = "PetalWidthCm", color = "green")

# %%
import sys

# %%
sys.version_info
# Out:
# sys.version_info(major=2, minor=7, micro=12, releaselevel='final', serial=0)

# %%
import seaborn as sns
sns.set(style = "ticks", color_codes = True)
Iris = sns.load_dataset("iris")
sns.swarmplot(x="PetalWidthCm", y="PetalLengthCm", data=iris, hue='Species')

# %%
sns.swarmplot(x='SepalWidthCm', y='SepalLengthCm', data=iris, hue='Species')
